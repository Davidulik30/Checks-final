# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn import preprocessing
from tqdm import tqdm_notebook


num_clusters = 6
train_count = 10000
plotted_point_count = 50

# %%
def predict(data, centroids, index):
    centroids, data = np.array(centroids), np.array(data)
    distances = []
    unit = data
    for center in centroids:
        d = unit - center
        t = (d) ** 2
        summ = np.math.sqrt(np.sum(t))
        distances.append(summ)
    #distances = np.reshape(distances, data.shape)
    closest_centroid = np.argmin(distances) #for dist in distances]
    #print(closest_centroid, index)
    return closest_centroid

# %%
dfStr = pd.read_csv('checks_str.txt', sep='\t')
dfTitles = pd.read_csv('checks_titles.txt', sep='\t')
names = pd.read_csv('id.txt', sep='\t', names=['idtov','name'])
data = pd.merge(dfStr, names, on='idtov')
print(data.head(100))
data = pd.merge(dfTitles, data, on='iddoc' )
# data['idtov'] = data['idtov'].astype(str)
data.head(100)
# print(data.shape)
# for indx, tmp in data.iterrows():
#     if type(data['idtov'][indx]) != str:
#         print(type(data['idtov'][indx]))
# Out:
#     iddoc idtov  count  price   summa  \
# 0   227FR   92N    4.0   68.0  272.00
# 1   22824   92N    2.0   68.0  136.00
# 2   228CE   92N    2.0   68.0  136.00
# 3   228CV   92N    2.0   68.0  136.00
# 4   228D3   92N    6.0   68.0  408.00
# 5   228F1   92N    6.0   68.0  408.00
# 6   229HD   92N    4.0   68.0  272.00
# 7   229IN   92N    1.0   68.0   68.00
# 8   22A4C   92N    1.0   68.0   68.00
# 9   22A7E   92N    2.0   68.0  136.00
# 10  22AFJ   92N    6.0   68.0  408.00
# 11  22AWF   92N    4.0   68.0  272.00
# 12  22AX1   92N    2.0   68.0  136.00
# 13  22AZ0   92N    2.0   68.0  136.00
# 14  22BEQ   92N    4.0   68.0  272.00
# 15  22BJO   92N    2.0   68.0  136.00
# 16  22BNL   92N    6.0   68.0  408.00
# 17  22BQ7   92N    2.0   68.0  136.00
# 18  22BQN   92N    1.0   68.0   68.00
# 19  22BUS   92N    2.0   68.0  136.00
# 20  22CJL   92N    1.0   68.0   68.00
# 21  22CZF   92N    2.0   68.0  131.92
# 22  22F72   92N    1.0   68.0   68.00
# 23  22THG   92N    4.0   68.0  272.00
# 24  22UHY   92N    3.0   68.0  204.00
# 25  22V9A   92N    2.0   68.0  136.00
# 26  22VLC   92N    4.0   68.0  244.80
# 27  22VO4   92N    2.0   68.0  136.00
# 28  22W51   92N    2.0   68.0  136.00
# 29  22XIN   92N    6.0   68.0  408.00
# ..    ...   ...    ...    ...     ...
# 70  23OTG   92N   10.0   69.0  621.00
# 71  23QGJ   92N    2.0   69.0  138.00
# 72  23R6P   92N    2.0   69.0  138.00
# 73  23TF6   92N    4.0   69.0  276.00
# 74  23V3S   92N    2.0   69.0  138.00
# 75  23VQM   92N    2.0   69.0  138.00
# 76  23VWG   92N    1.0   69.0   69.00
# 77  23W9G   92N    2.0   69.0  138.00
# 78  23XFH   92N    2.0   69.0  138.00
# 79  23XHW   92N    1.0   69.0   69.00
# 80  23YJT   92N    2.0   69.0  138.00
# 81  2401U   92N    1.0   69.0   69.00
# 82  240CE   92N    6.0   69.0  414.00
# 83  240KZ   92N    2.0   69.0  124.20
# 84  241Q0   92N    2.0   69.0  138.00
# 85  241UG   92N    2.0   69.0  138.00
# 86  24292   92N    4.0   69.0  276.00
# 87  242LV   92N    2.0   69.0  138.00
# 88  242WY   92N    4.0   69.0  276.00
# 89  243R3   92N    1.0   69.0   69.00
# 90  2442K   92N    4.0   69.0  276.00
# 91  247D6   92N    2.0   69.0  138.00
# 92  2482Y   92N    4.0   69.0  276.00
# 93  24878   92N    2.0   69.0  128.34
# 94  248KE   92N    2.0   69.0  138.00
# 95  248QZ   92N    4.0   69.0  276.00
# 96  248ZN   92N    4.0   69.0  276.00
# 97  249MW   92N    2.0   69.0  138.00
# 98  249OD   92N    2.0   69.0  138.00
# 99  249QN   92N    2.0   69.0  138.00
#
#                                                  name
# 0   Батарейка Duracell Turbo LR 6 2BL             ...
# 1   Батарейка Duracell Turbo LR 6 2BL             ...
# 2   Батарейка Duracell Turbo LR 6 2BL             ...
# 3   Батарейка Duracell Turbo LR 6 2BL             ...
# 4   Батарейка Duracell Turbo LR 6 2BL             ...
# 5   Батарейка Duracell Turbo LR 6 2BL             ...
# 6   Батарейка Duracell Turbo LR 6 2BL             ...
# 7   Батарейка Duracell Turbo LR 6 2BL             ...
# 8   Батарейка Duracell Turbo LR 6 2BL             ...
# 9   Батарейка Duracell Turbo LR 6 2BL             ...
# 10  Батарейка Duracell Turbo LR 6 2BL             ...
# 11  Батарейка Duracell Turbo LR 6 2BL             ...
# 12  Батарейка Duracell Turbo LR 6 2BL             ...
# 13  Батарейка Duracell Turbo LR 6 2BL             ...
# 14  Батарейка Duracell Turbo LR 6 2BL             ...
# 15  Батарейка Duracell Turbo LR 6 2BL             ...
# 16  Батарейка Duracell Turbo LR 6 2BL             ...
# 17  Батарейка Duracell Turbo LR 6 2BL             ...
# 18  Батарейка Duracell Turbo LR 6 2BL             ...
# 19  Батарейка Duracell Turbo LR 6 2BL             ...
# 20  Батарейка Duracell Turbo LR 6 2BL             ...
# 21  Батарейка Duracell Turbo LR 6 2BL             ...
# 22  Батарейка Duracell Turbo LR 6 2BL             ...
# 23  Батарейка Duracell Turbo LR 6 2BL             ...
# 24  Батарейка Duracell Turbo LR 6 2BL             ...
# 25  Батарейка Duracell Turbo LR 6 2BL             ...
# 26  Батарейка Duracell Turbo LR 6 2BL             ...
# 27  Батарейка Duracell Turbo LR 6 2BL             ...
# 28  Батарейка Duracell Turbo LR 6 2BL             ...
# 29  Батарейка Duracell Turbo LR 6 2BL             ...
# ..                                                ...
# 70  Батарейка Duracell Turbo LR 6 2BL             ...
# 71  Батарейка Duracell Turbo LR 6 2BL             ...
# 72  Батарейка Duracell Turbo LR 6 2BL             ...
# 73  Батарейка Duracell Turbo LR 6 2BL             ...
# 74  Батарейка Duracell Turbo LR 6 2BL             ...
# 75  Батарейка Duracell Turbo LR 6 2BL             ...
# 76  Батарейка Duracell Turbo LR 6 2BL             ...
# 77  Батарейка Duracell Turbo LR 6 2BL             ...
# 78  Батарейка Duracell Turbo LR 6 2BL             ...
# 79  Батарейка Duracell Turbo LR 6 2BL             ...
# 80  Батарейка Duracell Turbo LR 6 2BL             ...
# 81  Батарейка Duracell Turbo LR 6 2BL             ...
# 82  Батарейка Duracell Turbo LR 6 2BL             ...
# 83  Батарейка Duracell Turbo LR 6 2BL             ...
# 84  Батарейка Duracell Turbo LR 6 2BL             ...
# 85  Батарейка Duracell Turbo LR 6 2BL             ...
# 86  Батарейка Duracell Turbo LR 6 2BL             ...
# 87  Батарейка Duracell Turbo LR 6 2BL             ...
# 88  Батарейка Duracell Turbo LR 6 2BL             ...
# 89  Батарейка Duracell Turbo LR 6 2BL             ...
# 90  Батарейка Duracell Turbo LR 6 2BL             ...
# 91  Батарейка Duracell Turbo LR 6 2BL             ...
# 92  Батарейка Duracell Turbo LR 6 2BL             ...
# 93  Батарейка Duracell Turbo LR 6 2BL             ...
# 94  Батарейка Duracell Turbo LR 6 2BL             ...
# 95  Батарейка Duracell Turbo LR 6 2BL             ...
# 96  Батарейка Duracell Turbo LR 6 2BL             ...
# 97  Батарейка Duracell Turbo LR 6 2BL             ...
# 98  Батарейка Duracell Turbo LR 6 2BL             ...
# 99  Батарейка Duracell Turbo LR 6 2BL             ...
#
# [100 rows x 6 columns]
#     iddoc             docdate  return store  kassa seller collector idtov  \
# 0   227FR  2017-01-0308:14:07       0     N      1      H        2O   92N
# 1   227FU  2017-01-0308:14:08       0     N      1     3U        39   7P9
# 2   227FV  2017-01-0308:14:09       0     N      1     2O        39   38O
# 3   227FW  2017-01-0308:14:10       0     N      1     3U        39   9O0
# 4   227FX  2017-01-0308:14:11       0     N      1     2O        39   DJZ
# 5   227FY  2017-01-0308:14:12       0     N      1     2O        39    KY
# 6   227FZ  2017-01-0308:14:13       0     N      7     32         U   10H
# 7   227FZ  2017-01-0308:14:13       0     N      7     32         U   2OD
# 8   227G1  2017-01-0309:08:03       0     N      1     2O        41   DVV
# 9   227G1  2017-01-0309:08:03       0     N      1     2O        41   DVU
# 10  227G1  2017-01-0309:08:03       0     N      1     2O        41   AZ1
# 11  227G2  2017-01-0309:08:04       0     N      1     39         U   ISQ
# 12  227G3  2017-01-0309:08:05       0     N      1     32        41   ISW
# 13  227G3  2017-01-0309:08:05       0     N      1     32        41     B
# 14  227G4  2017-01-0309:08:05       0     N      1     2O        39   ZF2
# 15  227G4  2017-01-0309:08:05       0     N      1     2O        39    X5
# 16  227G5  2017-01-0309:08:06       0     N      1     2O        39   38O
# 17  227G5  2017-01-0309:08:06       0     N      1     2O        39   V5F
# 18  227G6  2017-01-0309:08:06       0     N      1     3Y        41    WD
# 19  227G6  2017-01-0309:08:06       0     N      1     3Y        41   1IL
# 20  227G7  2017-01-0309:08:07       0     N      1     47         5   E3T
# 21  227G8  2017-01-0309:08:08       0     N      1     47         5  123G
# 22  227G9  2017-01-0309:08:08       0     N      1     2O        39   QVJ
# 23  227G9  2017-01-0309:08:08       0     N      1     2O        39   QVD
# 24  227G9  2017-01-0309:08:08       0     N      1     2O        39   QVC
# 25  227GA  2017-01-0309:08:09       0     N      1     42        3E  11YI
# 26  227GA  2017-01-0309:08:09       0     N      1     42        3E  11VA
# 27  227GA  2017-01-0309:08:09       0     N      1     42        3E   LDZ
# 28  227GA  2017-01-0309:08:09       0     N      1     42        3E   18B
# 29  227GA  2017-01-0309:08:09       0     N      1     42        3E   6O6
# ..    ...                 ...     ...   ...    ...    ...       ...   ...
# 70  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PQ5
# 71  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PQ9
# 72  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PQC
# 73  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PQ2
# 74  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PUW
# 75  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PR1
# 76  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PQ1
# 77  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   Q22
# 78  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   PV7
# 79  227GR  2017-01-0310:59:55       0     N      5     2S        2Z    RF
# 80  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   XKK
# 81  227GR  2017-01-0310:59:55       0     N      5     2S        2Z  120F
# 82  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   RZ7
# 83  227GR  2017-01-0310:59:55       0     N      5     2S        2Z   WSK
# 84  227GS  2017-01-0310:54:51       0     N      7     2O        3E  13AI
# 85  227GS  2017-01-0310:54:51       0     N      7     2O        3E  12TQ
# 86  227GS  2017-01-0310:54:51       0     N      7     2O        3E  10Y9
# 87  227GU  2017-01-0310:59:50       0     N      7     32        41   K0Z
# 88  227GV  2017-01-0310:54:52       0     N      1     2A        47   QU9
# 89  227GX  2017-01-0310:59:52       0     N      1     2O        1X  11YI
# 90  227GX  2017-01-0310:59:52       0     N      1     2O        1X   UH0
# 91  227GX  2017-01-0310:59:52       0     N      1     2O        1X  134B
# 92  227GX  2017-01-0310:59:52       0     N      1     2O        1X   TN7
# 93  227GY  2017-01-0310:59:54       0     N      5     35        3E   6O6
# 94  227GY  2017-01-0310:59:54       0     N      5     35        3E    KX
# 95  227GZ  2017-01-0310:59:53       0     N      1     49        47   XEQ
# 96  227H0  2017-01-0310:59:58       0     N      1     32        1X  13Q3
# 97  227H3  2017-01-0311:00:14       0     N      5     49         U  157G
# 98  227H5  2017-01-0311:00:10       0     N      5     3E        39    KX
# 99  227H7  2017-01-0311:00:12       0     N      1     2O        25    9J
#
#     count   price    summa                                               name
# 0     4.0    68.0   272.00  Батарейка Duracell Turbo LR 6 2BL             ...
# 1     2.0     7.5    15.00  Подрозетник СЗМ3 д/бетон. стен                ...
# 2     1.0    48.0    48.00  Батарейка Duracell LR03 бл/2 81268853         ...
# 3     1.0    11.0    11.00  Подрозетник 68*47 д/полых стен PE 030 040     ...
# 4     8.0   182.0  1456.00  Лампа экон. Camelion LH 20W E14 4200К LH-FS-T2...
# 5     4.0    32.0   128.00  Кабель ВВГп 2* 2,5                            ...
# 6     6.0    20.0   120.00  Лампа ДШ 40W Е14 шар проз.                    ...
# 7     6.0    14.0    84.00  Патрон эл. Е14 керам. подвесной ASD           ...
# 8     4.0     4.3    17.20  уд.Болт шестигранн. М 8*60 DIN933 1191806000  ...
# 9     2.0     3.9     7.80  Болт шестигранн. М 8*50 DIN933 1191805000     ...
# 10    4.0     3.4    13.60  Болт шестигранн. М 8*40 DIN933 1191804000     ...
# 11    1.0   543.0   488.70  Пульт дистанцион. управления 2-х позиц. Y2 ES ...
# 12    2.0    32.0    64.00  Лампа  7W E14 Camelion  д/ночников DP 704 BL 4...
# 13    2.0    38.0    76.00  Батарейка Energizer  LR6 AA 638376            ...
# 14    2.0    45.0    90.00  Лампа шар мат. 60W Е27 P45  FR Philips        ...
# 15    1.0    48.0    48.00  Лампа галог. линейн.  500W 118мм              ...
# 16    1.0    48.0    48.00  Батарейка Duracell LR03 бл/2 81268853         ...
# 17    1.0    85.0    85.00  Батарейка Energizer  CR 2032                  ...
# 18    3.0    79.0   237.00  Лампа люм. труб. TLD 36W 54 Philips           ...
# 19    3.0     9.0    27.00  Стартер СК-220V 65W, LS-111-80W               ...
# 20    1.0  2070.0  2007.90  Сопло роторное (К5 - К7)                      ...
# 21    1.0  1010.0   979.70  Штангенциркуль LICOTA ШЦ-I-200 мм             ...
# 22    1.0    99.0    99.00  удNEO Розетка 2м с/з бел.                     ...
# 23    1.0    77.0    77.00  удNEO Выкл-ль 2кл бел.                        ...
# 24    1.0    57.0    57.00  удNEO Выкл-ль 1кл бел. 513-000200-200         ...
# 25   10.0    54.0   486.00  Розетка 2м  ОП РА16-237-В Хит                 ...
# 26    2.0   436.0   784.80  Колодка каучук 3гн 16A с/з 107 300 00         ...
# 27    4.0    77.0   277.20  Вилка штепс. HL угловая  с/з 000-704          ...
# 28   20.0    49.9   898.20  Провод ПВС 3* 2,5                             ...
# 29    8.0    40.0   288.00  Изолента ПВХ REXANT цветная 19*25мм 09-2206   ...
# ..    ...     ...      ...                                                ...
# 70   12.0   212.0  2289.60  LEZARD Mira Розетка 1м б/з жем.бел. 7013030121...
# 71    3.0   248.0   669.60  LEZARD Mira Розетка TV окон.жем.бел. 701303013...
# 72    3.0   405.0  1093.50  LEZARD Mira Розетка 1м комп.жем.бел. 701303013...
# 73    5.0   196.0   882.00  LEZARD Mira Выкл-ль 1кл жем.бел. 7013030100   ...
# 74    7.0   208.0  1310.40  LEZARD Mira Выкл-ль 2кл жем.бел. 7013030101   ...
# 75    2.0   216.0   388.80  LEZARD Mira Выкл-ль 1кл прох. жем.бел 70130301...
# 76   14.0   134.0  1688.40  LEZARD Mira Рамка 2м жем.бел.гориз. 7013000147...
# 77    2.0   189.0   340.20  LEZARD Mira Рамка 3м жем.бел.гориз. 7013000148...
# 78    4.0   228.0   820.80  LEZARD Mira Рамка 5м жем.бел. 7013000150      ...
# 79    3.0     8.0    21.60  Подрозетник СЗМ2 д/бетон стен                 ...
# 80    8.0   498.0  3585.60  Св-к ES точеч. 8371 бел.золото WH/GD          ...
# 81    2.0   599.0  1078.20  Св-к встраив. Ecola GX53 H4 хром FW53RGECB    ...
# 82    2.0   298.0   536.40  Лампа LED Ecola GX53 12W 2800K мат.T5LW12ELC  ...
# 83    8.0   132.0   950.40  Лампа LED HL  9W G5.3 3000K                   ...
# 84    8.0   173.0  1384.00  Лампа LED ES E14  5W  4200K свеча F           ...
# 85    3.0    98.0   294.00  Лампа LED Camelion  3W E14 4500K C35 220W     ...
# 86   12.0   192.0  2304.00  Лампа LED Feron G9 5W 4000K мат.LB-430        ...
# 87   20.0    28.0   560.00  Лампа галог. JC 20W G4 12V HB2 супер бел FERON...
# 88    1.0  2999.0  2849.05  Тепловая пушка Ballu BHP-3000CL 3kW 220V      ...
# 89    2.0    54.0   108.00  Розетка 2м  ОП РА16-237-В Хит                 ...
# 90    2.0    57.0   114.00  Выкл-ль 1кл  OП 0021 белый  10A Олимп         ...
# 91    3.0    98.0   294.00  Лампа LED LEEK  6W E27 4000K шарик LE CK1     ...
# 92    4.0   125.0   500.00  Лампа экон. КЭЛP-FS 20W Е27 4000K  ИЭК        ...
# 93    1.0    40.0    40.00  Изолента ПВХ REXANT цветная 19*25мм 09-2206   ...
# 94    1.0    21.4    21.40  Кабель ВВГп 2* 1,5                            ...
# 95    1.0  5629.0  5629.00  Тепловая пушка  газовая Ballu BHG-10М         ...
# 96    1.0  1397.0  1397.00  Наст. лампа  LEEK TL-121 4000K черн.          ...
# 97    1.0   862.0   862.00  Тепловентилятор Timberk TFH S20SMU 2000W наст....
# 98    5.0    21.4   107.00  Кабель ВВГп 2* 1,5                            ...
# 99    1.0    89.0    89.00  Автом.выкл. ИЭК ВА 47- 29  1р  20А            ...
#
# [100 rows x 12 columns]

# %%
# names = pd.read_csv('id.csv', sep='\t', names=['idtov','name'])
# # names['idtov'] = names['idtov'].astype(str)
# print(names.head())
# names.head()
# type(names['idtov'][0])

# %%
# data.join(names, on ='idtov')
# data.head()

# %%
#number_of_units_sold -  количество проданных единиц товара
tovs = data.groupby(['idtov']).sum() #общее кол-во товаров по id товара
tovs['number_of_units_sold'] = data.groupby(['idtov']).size()
tovs = tovs.sort_values(by = ['summa'], ascending=False)
tovs.head()
# Out:
#        return  kassa     count       price       summa  number_of_units_sold
# idtov
# L0         23  11586  141387.3   117992.40  6328975.73                  2624
# KY         30  23114  190703.7   162373.65  5857220.68                  5280
# IKW         8   3857   64382.0    46835.13  3366551.29                   833
# 2CZ        86  20434    4539.0  3334928.00  3333980.48                  4444
# O9W         3    952     196.0  3167875.00  3083935.80                   200

# %%
ch = data.groupby(['iddoc']).sum()
ch['count_uniq_good'] = data.groupby(['iddoc']).size()

# %%
checks = ch.drop(columns=["return","kassa","price"])
checks = checks[checks['count_uniq_good'] > 2]
checks = checks[checks['summa'] > 0]
checks.head()

#нормализация данных
checks = pd.DataFrame(preprocessing.normalize(checks, axis=0), index = checks.index.values)
checks.columns=["kolvo","summa","count_uniq_good"]
checks.head()

#обучили модель на тренировочном наборе
trainDF = pd.DataFrame(checks[:train_count])
train = trainDF.values
model = KMeans(n_clusters = num_clusters)
model.fit(train)
all_predictions = model.predict(train)

# %%
x_axis = train[:plotted_point_count, 0]
y_axis = train[:plotted_point_count, 1]
z_axis = train[:plotted_point_count, 2]
fig = plt.figure()#figsize=(18, 16))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel(xlabel="kolvo")
ax.set_ylabel(ylabel="summa")
ax.set_zlabel(zlabel="unique")
ax.scatter(x_axis, y_axis, z_axis, c=all_predictions[:plotted_point_count])

# %%
dfrm = pd.Series({'predicted':all_predictions})
trainDF['predicted'] = dfrm['predicted']
trainDF.head(15)

testCheck = pd.DataFrame(checks[train_count+10:train_count+11])
pred = model.predict(testCheck.values)
print(pred)
print(testCheck.head())

test_check_content = pd.DataFrame(data[data['iddoc'].isin(testCheck.index.values)])

test_check_content.head()
# Out:
# [3]
#           kolvo     summa  count_uniq_good
# 240T5  0.008858  0.003202         0.006084
#         iddoc             docdate  return store  kassa seller collector idtov  \
# 104085  240T5  2017-04-0812:38:47       0     N      7     2Y        2W   IKW
# 104086  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    9H
# 104087  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    9K
# 104088  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    R0
# 104089  240T5  2017-04-0812:38:47       0     N      7     2Y        2W   5ZT
#
#         count  price   summa  \
# 104085   70.0   52.9  3332.7
# 104086    4.0   82.0   295.2
# 104087    8.0   82.0   590.4
# 104088   15.0   13.0   175.5
# 104089   20.0   35.0   630.0
#
#                                                      name
# 104085  Кабель ВВГнг LSп 3* 2,5                       ...
# 104086  Автом.выкл. ИЭК ВА 47- 29  1р  16А            ...
# 104087  Автом.выкл. ИЭК ВА 47- 29  1р  25А            ...
# 104088  Коробка расп. узкая                           ...
# 104089  Кабель ВВГнг LSп 3* 1,5                       ...

# %%
group = trainDF[trainDF['predicted']==1]
group.shape
# Out:
# (23, 4)

# %%
c = []
for i in range(num_clusters):
    group = trainDF[trainDF['predicted']==i]
    c.append(group.mean().values[:-1])
# print(c)

col = ['r','g','b','m', 'y', 'c']
a = []

print(testCheck.shape)
for index, t in testCheck.iterrows():
#     print(model.predict(np.array([t.values])))
#     print(predict([t['kolvo'],t['summa'], t['count_uniq_good']], c, index))

    closest = model.predict(np.array([t.values]))
    ax.scatter(t['kolvo'], t['summa'], t['count_uniq_good'], c=col[closest[0]])
    similar_checks = pd.DataFrame(trainDF[trainDF['predicted']==closest[0]])
    check_content = pd.DataFrame(data[data["iddoc"]==index])
    
    #получить все товары из похожих чеков
    train_tov = pd.DataFrame(data[data['iddoc'].isin(similar_checks.index.values)])
    
    
    for check_inedx, tovar in check_content.iterrows():
#         print (tovar['idtov'])
        #отбираем все те чеки в которых встречаются эти товары
#         print(train_tov[train_tov['idtov'] == tovar['idtov']])
        a.append(train_tov[train_tov['idtov'] == tovar['idtov']])
        
    a = pd.concat(a)
    a = pd.DataFrame(a.groupby(['iddoc']).size().reset_index(name='count'))
    
    a = a.sort_values(by=['count', 'iddoc'], ascending=False)
#     print(a)
    
    b = []
    
#     print(b)
    for ind, k in a.iterrows():
        t = pd.DataFrame(data[data["iddoc"]==a.iloc[ind]['iddoc']])
        
        b.extend(t.values)
    b = pd.DataFrame(b, columns = data.columns)
    summ = b.groupby(['idtov']).sum()
    summ['count_good'] = b.groupby(['idtov']).size()
    summ = summ.sort_values(by = ['count_good'], ascending=False)
#     print(b)

summ = pd.merge(summ, names, on='idtov')
summ.head(15)
# Out:
# (1, 3)
#    idtov  return  kassa    count    price      summa  count_good  \
# 0    82X       0    318  21270.0    45.60   11848.80          76
# 1    6O6       0    235    136.0  2280.00    5056.00          57
# 2     9H       0    183    202.0  3944.00   16021.68          47
# 3    7M6       0    165  11700.0    19.35    4962.15          43
# 4    7P9       0    181    935.0   313.00    6731.90          41
# 5     9K       0    142    211.0  2876.00   16653.46          34
# 6    24W       0    119    306.0   135.00    1428.05          27
# 7     L0       0    111   2735.0  1182.00  113632.50          27
# 8    IKW       0    114   2795.0  1366.40  136727.46          26
# 9     KZ       0    117   1420.0   743.90   40026.32          25
# 10   F6N       0     95    823.0   439.30   15933.00          21
# 11  13TZ       0     91   5600.0     9.45    2372.40          21
# 12   5ZT       0     74   1435.0   699.20   46947.00          20
# 13    RF       0     86    471.0   144.00    3532.24          18
# 14    KY       0     81   1830.0   528.30   55074.00          17
#
#                                                  name
# 0   Дюбель-хомут круглый 11*18мм белый            ...
# 1   Изолента ПВХ REXANT цветная 19*25мм 09-2206   ...
# 2   Автом.выкл. ИЭК ВА 47- 29  1р  16А            ...
# 3   Дюбель-хомут круглый  5*10мм белый            ...
# 4   Подрозетник СЗМ3 д/бетон. стен                ...
# 5   Автом.выкл. ИЭК ВА 47- 29  1р  25А            ...
# 6   Шина соединит. 1ф до 63А (штырь)(54шт в 1м) ИЭ...
# 7   Кабель ВВГп 3* 2,5                            ...
# 8   Кабель ВВГнг LSп 3* 2,5                       ...
# 9   Кабель ВВГп 3* 1,5                            ...
# 10  Кабель TV SAT 703B Cu/AL/Cu  01-2431          ...
# 11  Дюбель-хомут прямоугольный 10*5мм белый       ...
# 12  Кабель ВВГнг LSп 3* 1,5                       ...
# 13  Подрозетник СЗМ2 д/бетон стен                 ...
# 14  Кабель ВВГп 2* 2,5                            ...

# %%
check_content.head()
# Out:
#         iddoc             docdate  return store  kassa seller collector idtov  \
# 104085  240T5  2017-04-0812:38:47       0     N      7     2Y        2W   IKW
# 104086  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    9H
# 104087  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    9K
# 104088  240T5  2017-04-0812:38:47       0     N      7     2Y        2W    R0
# 104089  240T5  2017-04-0812:38:47       0     N      7     2Y        2W   5ZT
#
#         count  price   summa  \
# 104085   70.0   52.9  3332.7
# 104086    4.0   82.0   295.2
# 104087    8.0   82.0   590.4
# 104088   15.0   13.0   175.5
# 104089   20.0   35.0   630.0
#
#                                                      name
# 104085  Кабель ВВГнг LSп 3* 2,5                       ...
# 104086  Автом.выкл. ИЭК ВА 47- 29  1р  16А            ...
# 104087  Автом.выкл. ИЭК ВА 47- 29  1р  25А            ...
# 104088  Коробка расп. узкая                           ...
# 104089  Кабель ВВГнг LSп 3* 1,5                       ...

# %%
for index, tov in check_content.iterrows():
#     print(tov)
    summ = summ[summ.idtov != tov.idtov]
summ = summ.sort_values(by='idtov', ascending=True)
print(summ)
# print(summ[summ['idtov']=='9H'])
# Out:
#     idtov  return  kassa  count    price     summa  count_good  \
# 285  104A       0      7    1.0    544.0    516.80           1
# 396  108Z       0      1    1.0    547.0    508.71           1
# 339  10AC       0      1    1.0    219.0    212.43           1
# 338   117       0      7   15.0     16.0    240.00           1
# 337  117Z       0      7    2.0    781.0   1452.66           1
# 186  1180       0      6    2.0   1840.0   1748.00           2
# 85    11B       0     22   21.0     63.0    301.40           4
# 36    11D       0     26   63.0    200.0   1465.00           8
# 52    11E       0     15   21.0    135.0    512.73           5
# 83    11F       0      8   35.0    180.0   1539.00           4
# 336  11FZ       0      7    1.0     59.0     53.10           1
# 335  11GK       0      5    4.0     97.0    376.36           1
# 334   11H       0      1    5.0     84.0    420.00           1
# 332  11SR       0      5  100.0      0.3     27.00           1
# 191  11SS       0      8  200.0      0.7     63.00           2
# 182  11SU       0      6  400.0      1.0    195.00           2
# 325  11SW       0      5  100.0      1.4    130.20           1
# 331  11SX       0      7  100.0      1.2    120.00           1
# 193  11T1       0      6    4.0     96.0    182.88           2
# 49   11T2       0     23  700.0      3.0    384.00           5
# 330  11T4       0      5  100.0      1.4    140.00           1
# 66   11T5       0     10  550.0      5.4    704.50           4
# 181  11T9       0      8  300.0      3.2    432.00           2
# 329  11TB       0      3  100.0      1.4    140.00           1
# 328  11TD       0      5  100.0      3.7    333.00           1
# 327  11TE       0      5  200.0      5.0    900.00           1
# 170  11YI       0      2   10.0    108.0    513.00           2
# 326  11ZS       0      1   25.0     10.0    225.00           1
# 340  1234       0      5    1.0    279.0    259.47           1
# 116  12AN       0     13    3.0   4575.0   4315.75           3
# ..    ...     ...    ...    ...      ...       ...         ...
# 115   VF3       0     13    4.0   1889.0   2331.70           3
# 204   VGE       0      7    1.0    650.0    650.00           1
# 206   VGG       0      1    1.0   1027.0    996.19           1
# 208   VLG       0      7    1.0   1607.0   1446.30           1
# 209   VM0       0      7    1.0    142.0    142.00           1
# 205   VUT       0      5    2.0    456.0    912.00           1
# 199   VUX       0      7    4.0    235.0    846.00           1
# 106   VWR       0      9    5.0     90.0    143.10           3
# 192   W2C       0     12    2.0   2266.0   2202.60           2
# 62    W7I       0     28   18.0    716.0   3034.05           4
# 110    X6       0     19    7.0     37.0     81.73           3
# 161   XEI       0     10    4.0    114.0    220.02           2
# 211   XX4       0      5    1.0   1198.0   1078.20           1
# 223   YHY       0      7    1.0    700.0    700.00           1
# 68    YIA       0     18    4.0   4231.0   3807.90           4
# 232    YT       0      1   15.0      8.6    116.10           1
# 233   YYF       0      5    5.0    456.0   2166.00           1
# 222   Z0S       0      1   20.0      5.0     90.00           1
# 159   Z0T       0      6    3.0    106.0    144.69           2
# 212   Z0U       0      5    2.0     48.0     96.00           1
# 221   Z2N       0      5    1.0    552.0    496.80           1
# 219   ZJ8       0      1   35.0    112.2   3534.30           1
# 218   ZJF       0      7    1.0    273.0    273.00           1
# 217   ZJG       0      7    1.0    462.0    415.80           1
# 95    ZKD       0     13   15.0    162.0    792.18           3
# 187   ZTN       0     12    2.0   4752.0   4395.60           2
# 37    ZTO       0     34    8.0  23653.0  21587.00           8
# 215   ZUC       0      7    1.0    210.0    189.00           1
# 213   ZUF       0      7    1.0    547.0    547.00           1
# 431   ZZR       0      1   15.0     59.0    796.50           1
#
#                                                   name
# 285  Автом. выкл. Legrand  2p C40A TX3             ...
# 396  Звонок ES DBQ16 WM 1M  IP44 черный            ...
# 339  Датчик Фотореле  ASD ФР-606 5A                ...
# 338  Лампа ЛОН  60W E27                            ...
# 337  Бокс Mono  12мод. внутр. 180-010001-012       ...
# 186  Бокс Mono  16мод. внутр. 180-010001-016       ...
# 85   Лампа ЛОН  95W Е27                            ...
# 36   Лампа ИК  15 E27                              ...
# 52   Лампа ИК  20 E27                              ...
# 83   Лампа ИК  30 Е27                              ...
# 336  ANAM Zunis Рамка 3м бел.TF TV Комп Аудио 7101 ...
# 335  LEZARD Nata Выкл-ль 1кл бел. 7100200100       ...
# 334  Лампа ИК  50 E40                              ...
# 332  Хомут нейлон  2,5* 80 черный REXANT           ...
# 191  Хомут нейлон  2,5*120 черный REXANT           ...
# 182  Хомут нейлон  3,0*150 белый REXANT            ...
# 325  Хомут нейлон  3,6*200 белый REXANT            ...
# 331  Хомут нейлон  4,0*200 черный REXANT           ...
# 193  Хомут нейлон  3,6*200 цветные REXANT          ...
# 49   Хомут нейлон  2,5*200 черный REXANT           ...
# 330  Хомут нейлон  5,0*200 черный REXANT           ...
# 66   Хомут нейлон  4,8*200 белый REXANT            ...
# 181  Хомут нейлон  4,8*250 белый REXANT            ...
# 329  Хомут нейлон  3,6*300 черный REXANT           ...
# 328  Хомут нейлон  7,6*300 черный REXANT           ...
# 327  Хомут нейлон  8,0*400 белый REXANT            ...
# 170  Розетка 2м  ОП РА16-237-В Хит                 ...
# 326  удПодрозетник 68*45 КУ1201 г/к  HEGEL         ...
# 340  Припой с канифолью 100гр 09-3223              ...
# 116  Бокс Mono  24мод. внутр. 180-010001-024       ...
# ..                                                 ...
# 115  Бокс Optibox 12 мод внутр IP40 белая дверь BVN...
# 204  Бокс Optibox  8 мод наружный IP40 белая дверь ...
# 206  Бокс Optibox 24 мод наружный IP40 белая дверь ...
# 208  УЗО Legrand 2р 40А 30ma TX3                   ...
# 209  LEZARD Mira Розетка TV окон. бел. 7010202130  ...
# 205  MAKEL Блок выкл-ль 1кл+ роз кр. сер ОП IP55   ...
# 199  MAKEL Розетка 1м с кр. серый  ОП IP55 36064029...
# 106  Коробка расп.  70*70*40  для о/п IP55 40-0200 ...
# 192  Бокс Optibox/Tekfor 36 мод внутр IP40 проз.дв ...
# 62   Автом. выкл. Legrand  1p C25A TX3             ...
# 110  Динрейка 20,0 см ИЭК                          ...
# 161  Перчатки СВС нитрил                           ...
# 211  Св-к ES LED STICK 18W 6500K 90см 84led        ...
# 223  Реле напряжения АЗМ 40А Ресанта               ...
# 68   Бокс Optibox 24 мод внутр IP40 прозр. дверь BV...
# 232  Провод ТРП 4 (ШТЛП 4 жилы) 01-5101            ...
# 233  Лампа экон. LEEK  65W E27 6400K SPL           ...
# 222  Хомут дюбельный ХД 7*150 серый                ...
# 159  Паяльная кислота (флюс ) с кисточкой  25мл 09-...
# 212  Припой с канифолью 10гр 09-3101               ...
# 221  Бокс Optibox  8 мод внутр IP40 белая дверь BVN...
# 219  Кабель ВВГп 2*10                              ...
# 218  Бокс Mirsa  6 мод наруж. 110.106              ...
# 217  Бокс Mirsa 12 мод наруж. 110.112              ...
# 95   Коробка расп.  85*85*40 IP55 ОП. SchE 35092   ...
# 187  Реле напряжения РН-104 9кВт                   ...
# 37   Реле напряжения РН-106 14кВт                  ...
# 215  Автом. выкл. Legrand  1p C 6A  TX3            ...
# 213  Автом. выкл. Legrand  2p C32A TX3             ...
# 431  Металлорукав d 20мм в ПВХ ИЭК                 ...
#
# [422 rows x 8 columns]
